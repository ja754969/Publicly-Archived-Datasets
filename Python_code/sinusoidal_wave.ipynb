# %% [markdown]
# <a href="https://colab.research.google.com/github/ja754969/Publicly-Archived-Datasets/blob/main/Python_code/sinusoidal_wave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![LINE_1627959159004.jpg](data:image/jpeg;base64,...)
#
# https://en.m.wikipedia.org/wiki/Sine_wave

# %%
# %matplotlib inline
import os 
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2.5,2.5,100) # measured in meters
x.shape
Amp = 2 # Amplitude, the peak deviation of the function from zero.
f = 0.5   # f, ordinary frequency, the number of oscillations (cycles) that occur each second of time.
omega = 2*np.pi*f   # ω = 2πf, angular frequency, the rate of change of the function argument in units of radians per second

φ = 1 #  phase angle (φ), specifies (in radians) where in its cycle the oscillation is at t = 0.
# When φ is non-zero, the entire waveform appears to be shifted in time by the amount φ/ω seconds. 
# A negative value represents a delay, and a positive value represents an advance.
y = Amp*np.sin(omega*x-φ) # Angle, in radians (2π rad equals 360 degrees)

plt.plot(x,y)
plt.grid(color='gray', linestyle=':', linewidth=2, alpha = 0.5)
plt.axis([-2.5, 2.5, -2.5, 2.5])
plt.xticks(np.arange(-2.5, 2.5, step=0.5))
# Out:
# ([<matplotlib.axis.XTick at 0x7fb91d152b50>,
# ...
#  <a list of 10 Text major ticklabel objects>)
